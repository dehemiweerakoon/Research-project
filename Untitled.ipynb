# %%
import json
import os

def load_training_data_from_file(json_file):
    """Load a single JSON annotated resume and return spaCy format"""
    with open(json_file, "r", encoding="utf-8") as f:
        data = json.load(f)
    
    text = data["text"]
    entities = []
    for start, end, label in data["annotations"]:
        entities.append((start, end, "SKILL"))  # Keep only SKILL
    return [(text, {"entities": entities})]

# Folder containing all JSON annotated resumes
folder_path = "ResumesJsonAnnotated"

TRAIN_DATA = []

# Loop through all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".json"):
        file_path = os.path.join(folder_path, filename)
        TRAIN_DATA.extend(load_training_data_from_file(file_path))

# %%
TRAIN_DATA[0]
# Out:
# ('One97 Communications Limited \nData Scientist Jan 2019 to Till Date \nDetect important information from images and redact\nrequired fields. YOLO CNN Object-detection, OCR\nInsights, find anomaly or performance drop in all\npossible sub-space. \nPredict the Insurance claim probability. Estimate the\npremium amount to be charged\nB.Tech(Computer Science) from SGBAU university in\n2017. \nM.Tech (Computer Science Engineering) from Indian\nInstitute of Technology (IIT), Kanpur in 2019WORK EXPERIENCE\nEDUCATIONMACY WILLIAMS\nDATA SCIENTIST\nData Scientist working  on problems related to market research and customer analysis. I want to expand my arsenal of\napplication building and work on different kinds of problems. Looking for a role where I can work with a coordinative team\nand exchange knowledge during the process.\nJava, C++, Python, Machine Learning, Algorithms, Natural Language Processing, Deep Learning, Computer Vision, Pattern\nRecognition, Data Science, Data Analysis, Software Engineer, Data Analyst, C, PySpark, Kubeflow.ABOUT\nSKILLS\nCustomer browsing patterns.\nPredict potential RTO(Return To Origin) orders for e-\ncommerce.\nObject Detection.PROJECTS\nACTIVITES',
#  {'entities': [(657, 665, 'SKILL'),
#    (822, 828, 'SKILL'),
#    (811, 815, 'SKILL'),
#    (781, 790, 'SKILL'),
#    (877, 887, 'SKILL'),
#    (194, 205, 'SKILL'),
#    (442, 452, 'SKILL'),
#    (1007, 1014, 'SKILL'),
#    (30, 44, 'SKILL'),
#    (153, 162, 'SKILL'),
#    (329, 345, 'SKILL'),
#    (102, 108, 'SKILL'),
#    (889, 902, 'SKILL'),
#    (942, 954, 'SKILL'),
#    (1031, 1037, 'SKILL'),
#    (1147, 1155, 'SKILL'),
#    (734, 737, 'SKILL'),
#    (575, 590, 'SKILL'),
#    (956, 969, 'SKILL'),
#    (904, 919, 'SKILL'),
#    (802, 809, 'SKILL'),
#    (817, 818, 'SKILL'),
#    (164, 167, 'SKILL'),
#    (604, 612, 'SKILL'),
#    (838, 846, 'SKILL'),
#    (971, 988, 'SKILL'),
#    (338, 345, 'SKILL'),
#    (267, 278, 'SKILL'),
#    (772, 780, 'SKILL'),
#    (379, 380, 'SKILL'),
#    (913, 919, 'SKILL'),
#    (6, 20, 'SKILL'),
#    (868, 887, 'SKILL'),
#    (763, 767, 'SKILL'),
#    (30, 34, 'SKILL'),
#    (860, 887, 'SKILL'),
#    (980, 988, 'SKILL'),
#    (1130, 1146, 'SKILL'),
#    (921, 928, 'SKILL'),
#    (387, 415, 'SKILL'),
#    (830, 846, 'SKILL'),
#    (1016, 1024, 'SKILL'),
#    (582, 590, 'SKILL'),
#    (1056, 1064, 'SKILL'),
#    (293, 300, 'SKILL'),
#    (555, 563, 'SKILL'),
#    (848, 858, 'SKILL'),
#    (645, 656, 'SKILL'),
#    (990, 1002, 'SKILL'),
#    (860, 876, 'SKILL'),
#    (168, 176, 'SKILL'),
#    (995, 1002, 'SKILL'),
#    (324, 328, 'SKILL'),
#    (929, 940, 'SKILL'),
#    (251, 260, 'SKILL'),
#    (595, 603, 'SKILL'),
#    (85, 96, 'SKILL'),
#    (404, 415, 'SKILL'),
#    (329, 337, 'SKILL'),
#    (971, 979, 'SKILL'),
#    (645, 665, 'SKILL'),
#    (142, 145, 'SKILL'),
#    (595, 612, 'SKILL'),
#    (868, 876, 'SKILL'),
#    (670, 674, 'SKILL'),
#    (35, 44, 'SKILL'),
#    (129, 135, 'SKILL'),
#    (1084, 1087, 'SKILL'),
#    (231, 236, 'SKILL'),
#    (1120, 1128, 'SKILL')]})

# %%
import spacy
from spacy.training.example import Example
import random

# %%
# Start with a blank English pipeline
nlp = spacy.blank("en")

# Add NER pipe
if "ner" not in nlp.pipe_names:
    ner = nlp.add_pipe("ner")
else:
    ner = nlp.get_pipe("ner")

# Add the SKILL label
ner.add_label("SKILL")
# Out:
# 1

# %%
def clean_annotations(train_data):
    cleaned = []
    for text, ann in train_data:
        entities = ann["entities"]
        # Sort by start index
        entities = sorted(entities, key=lambda x: (x[0], x[1]))
        non_overlapping = []
        prev_end = -1
        for start, end, label in entities:
            if start >= prev_end:  # only keep if it doesn't overlap
                non_overlapping.append((start, end, label))
                prev_end = end
        cleaned.append((text, {"entities": non_overlapping}))
    return cleaned

TRAIN_DATA = clean_annotations(TRAIN_DATA)

# %%
TRAIN_DATA = TRAIN_DATA[1:200]

# %%
# import re
# import unicodedata

# def clean_text(text):
#     # Remove surrogate characters (emojis, weird symbols)
#     text = re.sub(r'[\ud800-\udfff]', '', text)
#     # Normalize Unicode characters
#     text = unicodedata.normalize('NFKC', text)
#     # Optional: remove other non-printable characters
#     text = ''.join(c for c in text if c.isprintable())
#     return text

# # Apply to all training data
# TRAIN_DATA = [(clean_text(text), annotations) for text, annotations in TRAIN_DATA]

# %%
# Initialize weights and transitions properly
nlp.initialize(
    lambda: [Example.from_dict(nlp.make_doc(text), annotations) for text, annotations in TRAIN_DATA]
)
# Out:
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Yogesh Chandra Pandey Mobile: +91--7017692645
# Mobi..." with entities "[(22, 28, 'SKILL'), (103, 106, 'SKILL'), (142, 153...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ARUN KUMAR U.C.
#
# Mob :+91 9745004628         Em..." with entities "[(13, 14, 'SKILL'), (48, 53, 'SKILL'), (65, 67, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ATHULIA GOPI
# KottalilThoppil (H)
# Chumathra P athul..." with entities "[(61, 66, 'SKILL'), (67, 70, 'SKILL'), (83, 85, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Attila László Joó, PhD
# External advisor
# PhD Civil ..." with entities "[(19, 22, 'SKILL'), (32, 39, 'SKILL'), (50, 58, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
#
# Barbara Farman,  Hair, Makeup and Groo..." with entities "[(74, 77, 'SKILL'), (372, 379, 'SKILL'), (443, 447...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# 2632  La Cienega Avenue      Los Angeles, Califo..." with entities "[(102, 105, 'SKILL'), (545, 550, 'SKILL'), (802, 8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Bethany Newell, Manicurist
# www.cloutierre..." with entities "[(54, 57, 'SKILL'), (805, 811, 'SKILL'), (834, 839...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Bic Owen , Wardrobe Stylist
# www.cloutierremix.com..." with entities "[(47, 50, 'SKILL'), (174, 185, 'SKILL'), (207, 214...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Graphic & Web DesignerBince George Erattayanickal ..." with entities "[(10, 13, 'SKILL'), (94, 97, 'SKILL'), (129, 134, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "  DR.SANTOSH KAKADE
#                             ..." with entities "[(210, 212, 'SKILL'), (214, 221, 'SKILL'), (242, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text " BIOGRAPHY   Dr. Kunal Aneja M.B.B.S., M.S. (Ortho..." with entities "[(29, 30, 'SKILL'), (71, 78, 'SKILL'), (90, 91, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "aa PASSPORT NO-M0824097              Z
#  CURRICULAM..." with entities "[(0, 2, 'SKILL'), (3, 11, 'SKILL'), (161, 166, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#  Carla Kay , Manicurist
# www.cloutierremix.c..." with entities "[(49, 52, 'SKILL'), (488, 492, 'SKILL'), (555, 560...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
#
# Carlos Ortiz,  Hairstylist
# www.clouti..." with entities "[(58, 61, 'SKILL'), (221, 225, 'SKILL'), (903, 905...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# 2632  La Cienega Avenue      Los Angeles, Califo..." with entities "[(102, 105, 'SKILL'), (207, 212, 'SKILL'), (493, 4...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# 2632  La Cienega Avenue      Los Angeles, Cali..." with entities "[(104, 107, 'SKILL'), (224, 231, 'SKILL'), (561, 5...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
# Chantal Moore,  Makeup Artist & Men’s Gr..." with entities "[(76, 79, 'SKILL'), (219, 223, 'SKILL'), (375, 379...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Charles McNair,  Hairstylist
# www.cloutierremix.co..." with entities "[(0, 7, 'SKILL'), (48, 51, 'SKILL'), (211, 219, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Cheryl Calo,  Hairstylist and Makeup Artis..." with entities "[(71, 74, 'SKILL'), (278, 279, 'SKILL'), (531, 534...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
#           NAMECHIRAG (First Name)..." with entities "[(0, 10, 'SKILL'), (128, 136, 'SKILL'), (151, 162,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
#
# Christophe Saluzzo, Hairstylist
# www.c..." with entities "[(63, 66, 'SKILL'), (407, 414, 'SKILL'), (645, 647...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
# Claudia Alonso,  Wardrobe Stylist
# www.c..." with entities "[(63, 66, 'SKILL'), (231, 237, 'SKILL'), (449, 455...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# SURES..." with entities "[(109, 114, 'SKILL'), (129, 134, 'SKILL'), (135, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Collier Strong,  Makeup Artist
# www.clouti..." with entities "[(58, 61, 'SKILL'), (498, 502, 'SKILL'), (1033, 10...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ALEX LUDIGA
# P.O BOX 75645-00200
# NAIROBI 0713789462..." with entities "[(16, 19, 'SKILL'), (62, 67, 'SKILL'), (68, 71, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "345 W. Fullerton Pkwy. #2101
# Chicago, IL 60614-285..." with entities "[(109, 118, 'SKILL'), (158, 164, 'SKILL'), (170, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULAM VITAE
# AIM   :        To achieve good sk..." with entities "[(35, 42, 'SKILL'), (48, 53, 'SKILL'), (113, 119, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "STEPHEN KARANJA NJOROGE,
# P.O Box 16461, 20100 Naku..." with entities "[(29, 32, 'SKILL'), (54, 59, 'SKILL'), (79, 84, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text " 1
#
#  CURRICULUM VITAE
#
# Prof.  Vinod Kumar PA..." with entities "[(8, 18, 'SKILL'), (137, 144, 'SKILL'), (173, 183,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Juan Antonio Aguilar Garib
# Curriculum Vitae
# Fecha:..." with entities "[(27, 37, 'SKILL'), (214, 216, 'SKILL'), (246, 250...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Juan Antonio Aguilar Garib
# Curriculum Vitae
# Fecha:..." with entities "[(27, 37, 'SKILL'), (178, 180, 'SKILL'), (526, 534...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Juan Antonio Aguilar-Garib
# Resume
# Date: January 20..." with entities "[(27, 33, 'SKILL'), (77, 79, 'SKILL'), (114, 123, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SATYAM RICHHARIYA
# Contact No. +918375887854
# E-mail..." with entities "[(61, 66, 'SKILL'), (67, 70, 'SKILL'), (108, 120, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Abdulla RS
# #18-15/1, MM Temple St, Old Pet,..." with entities "[(0, 6, 'SKILL'), (28, 30, 'SKILL'), (64, 66, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Bio-data
# Name Merrnosh Ichhaporria
# Date of Birth 1..." with entities "[(4, 8, 'SKILL'), (65, 79, 'SKILL'), (86, 95, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CHETAN SONI
# B.Tech (Hons.) Mechanical Engineering
# ..." with entities "[(14, 18, 'SKILL'), (27, 37, 'SKILL'), (38, 49, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "BIO DATA
# Personal Details
# Name :DIGVIJAY
# Father’s ..." with entities "[(4, 8, 'SKILL'), (9, 17, 'SKILL'), (178, 187, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text " Yuvraj Balu Dagade
#   Email Id:dagadeyuvraj19@gma..." with entities "[(23, 28, 'SKILL'), (47, 52, 'SKILL'), (53, 56, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "T e r r y     Ku n y
# CURRICULUM     VITÆ
# 240  ..." with entities "[(4, 5, 'SKILL'), (23, 33, 'SKILL'), (183, 191, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Toni P. Robinson, M.S., J.D.
# 100 Memorial Drive, #..." with entities "[(18, 19, 'SKILL'), (42, 47, 'SKILL'), (111, 117, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "C. Anthony Palumbo
# 19 Garden St, Apt 28
# Cambridge,..." with entities "[(0, 1, 'SKILL'), (88, 95, 'SKILL'), (118, 131, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "HARSH SHARMA
# H.NO.59, R.K.Puram
# Gali no:2A near Se..." with entities "[(22, 23, 'SKILL'), (48, 51, 'SKILL'), (94, 99, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VINEET	MATHRADAS		Way	No.	3023,	House	No.	1918	PO	..." with entities "[(47, 49, 'SKILL'), (50, 53, 'SKILL'), (58, 60, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                         RESUME
# Name:            ..." with entities "[(25, 31, 'SKILL'), (118, 122, 'SKILL'), (189, 199...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VIRAK V GANDHI
# Bhatiya Chakla, Gandhi Street, Mund..." with entities "[(163, 168, 'SKILL'), (183, 188, 'SKILL'), (189, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VRINDA VISWAMBHARAN
# korumbooru(H), Mudakuzha(PO), ..." with entities "[(45, 47, 'SKILL'), (94, 99, 'SKILL'), (100, 103, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                  «  Curriculum Vi..." with entities "[(37, 47, 'SKILL'), (217, 223, 'SKILL'), (255, 260...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURICULUM VITAE
# PERSONAL DETAILS
# NAME:  Nick Wamw..." with entities "[(17, 25, 'SKILL'), (114, 119, 'SKILL'), (154, 159...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "WENDY B. MILLER
# 6 Phillips St. #4
# Boston, MA 0211..." with entities "[(35, 41, 'SKILL'), (84, 93, 'SKILL'), (128, 138, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "WILLIAM CHU
# 295 Harvard Street #601
# Cambridge, MA ..." with entities "[(111, 121, 'SKILL'), (142, 145, 'SKILL'), (178, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Yukihiro WADA
# 69 Holland St., Apt. #A, Somerville,..." with entities "[(66, 69, 'SKILL'), (110, 117, 'SKILL'), (120, 128...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
#
#      ABIN JOY
# Contact No:
# +919846460616..." with entities "[(0, 6, 'SKILL'), (82, 87, 'SKILL'), (106, 109, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Md. Shaiyad Hussain
# Plot#151 & 152, Aali vi..." with entities "[(0, 6, 'SKILL'), (114, 119, 'SKILL'), (136, 139, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Page | 1CURRICULUM VITAE
# WANGILA Abraham Masinde
# E..." with entities "[(49, 54, 'SKILL'), (71, 76, 'SKILL'), (77, 80, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To work with an organization where my learning and..." with entities "[(3, 7, 'SKILL'), (16, 28, 'SKILL'), (38, 46, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ákos Pohl
# Chief Executive Manager
# MSC in Civil Eng..." with entities "[(26, 33, 'SKILL'), (34, 37, 'SKILL'), (41, 58, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Amber Dreadon,  Makeup Artist
# www.cloutie..." with entities "[(57, 60, 'SKILL'), (532, 536, 'SKILL'), (614, 619...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Anju Sasi
# Chempilakkal  (H) Kanjar P.O
# Idukk..." with entities "[(98, 103, 'SKILL'), (104, 107, 'SKILL'), (157, 17...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ANJU THOMAS ANNAMMA
# E-mail: anjuthomas2296@gmail.c..." with entities "[(43, 48, 'SKILL'), (49, 52, 'SKILL'), (53, 58, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Curriculum Vitae (CV)
# Kaviyarajan Kannan,
# 13/3009-..." with entities "[(0, 10, 'SKILL'), (18, 20, 'SKILL'), (115, 120, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
# Anna Lyles , Hairstylist
# www.cloutierremi..." with entities "[(52, 55, 'SKILL'), (199, 205, 'SKILL'), (516, 527...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# CAREER OBJECTIVE
# To work in a firm with a p..." with entities "[(0, 6, 'SKILL'), (27, 31, 'SKILL'), (49, 61, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#  April Chaney,  Hairstylist and Makeup Arti..." with entities "[(73, 76, 'SKILL'), (617, 625, 'SKILL'), (724, 730...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Archana Nair A
# Aiswarya House, Manjinikkara
# Omallo..." with entities "[(81, 86, 'SKILL'), (117, 122, 'SKILL'), (139, 144...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# NISHANT ..." with entities "[(231, 237, 'SKILL'), (254, 259, 'SKILL'), (275, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
#                                            ..." with entities "[(0, 6, 'SKILL'), (542, 547, 'SKILL'), (548, 551, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "KARTHIK THIRUMALASETTY
# Hs.no:12-5-3 green house, m..." with entities "[(23, 25, 'SKILL'), (36, 41, 'SKILL'), (82, 87, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Page 1 of 4
#  SAMER ADI
# Oman – Mobile:  00968 997..." with entities "[(32, 38, 'SKILL'), (76, 79, 'SKILL'), (89, 97, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# Sana Junaid
# Address: Villa no 672..." with entities "[(0, 10, 'SKILL'), (105, 116, 'SKILL'), (121, 133,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Curriculum     Vitae
# Kokula.Bhanuchander
# Mechan..." with entities "[(0, 10, 'SKILL'), (44, 54, 'SKILL'), (55, 63, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                                  ..." with entities "[(149, 155, 'SKILL'), (189, 194, 'SKILL'), (209, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
#     SARIKA SREEJITH                        ..." with entities "[(0, 6, 'SKILL'), (75, 80, 'SKILL'), (99, 104, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Shabina P
# Email: shabi0208@yahoo.co.in
# Phone: +9..." with entities "[(11, 16, 'SKILL'), (41, 46, 'SKILL'), (80, 87, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Shajudheen N
#     Sohar ,Oman
#     E mail–  nshaju..." with entities "[(56, 61, 'SKILL'), (62, 65, 'SKILL'), (70, 71, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHAMEEL IQBAL
# Apartment No. 02, Anjum Mansion,
# A.M..." with entities "[(49, 50, 'SKILL'), (136, 141, 'SKILL'), (156, 159...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Curriculum Vitae
# JAGADEESHA SHETTY, MD
# 1265 Wa..." with entities "[(2, 12, 'SKILL'), (66, 78, 'SKILL'), (117, 123, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# SHYAMA C
# PO BOX 1153
# Muttrah
# PC 114
# ..." with entities "[(21, 22, 'SKILL'), (23, 25, 'SKILL'), (26, 29, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "S
# INGARAVELU
# .B
# Email:
# singaravelued@gmail.com
# Fin..." with entities "[(16, 21, 'SKILL'), (37, 42, 'SKILL'), (43, 46, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CVCV
# Saud Ali Habib AL-Jardani
# Personal Statement
# ..." with entities "[(31, 39, 'SKILL'), (61, 70, 'SKILL'), (77, 86, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# AMANDEEP SINGH
# Electrical Engineer       ..." with entities "[(0, 6, 'SKILL'), (24, 34, 'SKILL'), (35, 43, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "W. A. Sullivan CV 1 Walter A. (Bill) Sullivan Depa..." with entities "[(15, 17, 'SKILL'), (46, 56, 'SKILL'), (60, 67, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SUNIL PAWAR
# Professional Qualification :
# B.B.A (B..." with entities "[(12, 24, 'SKILL'), (25, 38, 'SKILL'), (49, 69, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#                                              RES..." with entities "[(47, 53, 'SKILL'), (391, 395, 'SKILL'), (426, 431...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# SWAPNA .C.S
# Mobile: +971 54 7197274, +971 52 48..." with entities "[(10, 11, 'SKILL'), (15, 21, 'SKILL'), (101, 106, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Lawrence Swift
# 1234  My Drive, Huntington Beach,..." with entities "[(9, 14, 'SKILL'), (26, 31, 'SKILL'), (148, 153, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                   CURRICULUM VITAE
# ADDRESS       ..." with entities "[(19, 29, 'SKILL'), (172, 177, 'SKILL'), (178, 181...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#  RE S Ü M E E
#
# Erfahrener Allround Manager ..." with entities "[(12, 13, 'SKILL'), (42, 49, 'SKILL'), (191, 201, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#  R E S U M É
#
# Bred ledelsesmæssig erfaring..." with entities "[(5, 6, 'SKILL'), (13, 14, 'SKILL'), (253, 258, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Arockia Juslin Deepan
# Dubai, UAE
# Mobile: 97155805..." with entities "[(34, 40, 'SKILL'), (55, 60, 'SKILL'), (76, 81, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#  SU M M A R Y
#
# Experienced senior executive..." with entities "[(8, 9, 'SKILL'), (14, 15, 'SKILL'), (34, 40, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "TAMARA B. CHARM
# 358 Washington Street, Apt.1
# Some..." with entities "[(10, 15, 'SKILL'), (97, 106, 'SKILL'), (141, 151,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Tamas Futo
# Executive Civil engineer
# MSC in Ci..." with entities "[(32, 40, 'SKILL'), (41, 44, 'SKILL'), (48, 65, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                                  ..." with entities "[(123, 128, 'SKILL'), (129, 132, 'SKILL'), (260, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                      CURRICULUM VITAE
# MD.KAREEMUD..." with entities "[(22, 32, 'SKILL'), (86, 92, 'SKILL'), (138, 141, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Terry Kuny
#  CURRICULUM VITÆ
#  240 Fairmont Ave,..." with entities "[(14, 24, 'SKILL'), (105, 110, 'SKILL'), (111, 114...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Oniel Conroy Campbell
# 26 Shakespeare Avenue, Duhan..." with entities "[(53, 57, 'SKILL'), (101, 104, 'SKILL'), (131, 149...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "DEEPIKA KAUSHIK Contact No.: +91 9871904629 (M)
#   ..." with entities "[(45, 46, 'SKILL'), (190, 195, 'SKILL'), (215, 220...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ANU HARI BHARDWAJ
#
# Mobile: 07043030903       Tel ..." with entities "[(20, 26, 'SKILL'), (103, 106, 'SKILL'), (119, 131...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Resume
# PersonalDetails:- RAAKESH.S.MAHADIK.
#  -----..." with entities "[(0, 6, 'SKILL'), (251, 257, 'SKILL'), (301, 312, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PROFILE
# A data science professional with 1 years o..." with entities "[(10, 14, 'SKILL'), (15, 22, 'SKILL'), (23, 35, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#   CURRICULUM
# Arjun pandey
# House no. 135 sa..." with entities "[(9, 19, 'SKILL'), (93, 99, 'SKILL'), (154, 159, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MOHAMED  SHAHID
# Email: mshahid..." with entities "[(36, 41, 'SKILL'), (56, 61, 'SKILL'), (62, 65, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# CA. SONA  A. DEVASSY,  B.Com, ACA..." with entities "[(0, 10, 'SKILL'), (42, 45, 'SKILL'), (47, 50, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ALI NASSRULLAH  ALI ALOOSH
# Email: alialoosh012@gma..." with entities "[(27, 32, 'SKILL'), (47, 52, 'SKILL'), (53, 56, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Md. MijanurRahman
# Mobile: 008801779427505
# E-Mail: ..." with entities "[(18, 24, 'SKILL'), (64, 67, 'SKILL'), (75, 85, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Name: Marwa Dawood Hassan Alzadjali
# Email: marawi..." with entities "[(37, 42, 'SKILL'), (61, 64, 'SKILL'), (84, 89, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Dheeraj S. Sharma
# Date of Birth: 29th May, 1983.  ..." with entities "[(161, 166, 'SKILL'), (167, 170, 'SKILL'), (285, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
#                            ..." with entities "[(0, 10, 'SKILL'), (183, 194, 'SKILL'), (224, 230,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# ...
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Elizabeth L. Richeson, Ph.D., M.S. PsyPharm
# Practi..." with entities "[(23, 25, 'SKILL'), (30, 31, 'SKILL'), (44, 52, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Priya  Elza
# Jacob
# Phone: 0091-9995532188
# Em..." with entities "[(0, 6, 'SKILL'), (25, 30, 'SKILL'), (48, 53, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "   Key Skills  Loan Disbursement   Strategic Plann..." with entities "[(7, 13, 'SKILL'), (15, 19, 'SKILL'), (35, 53, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RAJESH KUMARRAJESH KUMAR
# : 63, Keshav Nagar, Pal ..." with entities "[(116, 121, 'SKILL'), (122, 125, 'SKILL'), (126, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# RRAAJJEESSHH  KKUUMMAARR
#
# : 63, Keshav Naga..." with entities "[(125, 130, 'SKILL'), (131, 134, 'SKILL'), (357, 3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME      (Currently in Ruwi, Muscat on visit vi..." with entities "[(0, 6, 'SKILL'), (42, 47, 'SKILL'), (210, 215, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Premananda Das
# B-131, New Ashok Nagar, New ..." with entities "[(0, 6, 'SKILL'), (85, 88, 'SKILL'), (89, 94, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE:
# Mr. Fredrick Hezekiah Owino Oden..." with entities "[(0, 10, 'SKILL'), (53, 58, 'SKILL'), (68, 73, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RAFIK MICHAEL WARD
# 143 Albany Street - Apt. 221B
# ..." with entities "[(105, 114, 'SKILL'), (144, 154, 'SKILL'), (183, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "UBAIS.T
# Falaj Al-Qabael
# Sohar
# Sultanate of Oman
# D..." with entities "[(64, 71, 'SKILL'), (87, 95, 'SKILL'), (174, 185, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Elke Naumburg Resume
#  1NAME ELKE NAUMBURG
# TITL..." with entities "[(14, 20, 'SKILL'), (78, 88, 'SKILL'), (89, 92, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# PHILLIP R. GOETZE
# goetze@glorietageo.com
#
# T..." with entities "[(12, 13, 'SKILL'), (42, 45, 'SKILL'), (70, 91, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "REDDY GANTA
# Environmental Scientist
#
# GLORIET..." with entities "[(14, 27, 'SKILL'), (28, 37, 'SKILL'), (52, 62, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "REDDY GANTA
# Agricultural Infomatics Scientist
# GLOR..." with entities "[(36, 45, 'SKILL'), (55, 65, 'SKILL'), (67, 70, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sagar Talreja
# B2/39 Ashok Vihar Phase 2, New Delhi..." with entities "[(82, 87, 'SKILL'), (102, 107, 'SKILL'), (108, 111...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Resume
# Dinesh Madhavan Nair, 402, Family Pharmacy ..." with entities "[(0, 6, 'SKILL'), (41, 49, 'SKILL'), (50, 58, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "KIRAN SHIVAPOOJI
# Address: At: Bachanal
# Post: Rajan..." with entities "[(121, 126, 'SKILL'), (127, 130, 'SKILL'), (160, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NIGITHA XAVIER
# Anjiparambil House
# Elamakkara P.O
# V..." with entities "[(123, 128, 'SKILL'), (142, 147, 'SKILL'), (148, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                        A.MOHAMMED FAZIL          ..." with entities "[(78, 83, 'SKILL'), (84, 87, 'SKILL'), (113, 122, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cheat Sheet www.mapdb.org
# Maven
# <dependency>
#     <..." with entities "[(26, 31, 'SKILL'), (33, 43, 'SKILL'), (226, 234, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Sanafathima Sayyed
# #Third Cross Road, Patel..." with entities "[(0, 6, 'SKILL'), (60, 66, 'SKILL'), (129, 134, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# HEMANT GANGWAR
# +91 9891621755
# WZ 694 Narain..." with entities "[(0, 6, 'SKILL'), (106, 111, 'SKILL'), (112, 115, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Séminaire Qualité de l’air et santé de l’enfant – ..." with entities "[(1336, 1339, 'SKILL'), (1580, 1583, 'SKILL'), (15...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# CURR..." with entities "[(46, 56, 'SKILL'), (107, 113, 'SKILL'), (182, 187...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# MOHD SHADAB
# Address:59/71-B, Paka..." with entities "[(0, 10, 'SKILL'), (105, 111, 'SKILL'), (151, 156,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MUHAMMAD IQBAL HOSSAIN
# Mobile : 0096894864966
# e-..." with entities "[(24, 30, 'SKILL'), (71, 76, 'SKILL'), (77, 80, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J. MADISON ILER
# 143 Albany St. #313A
# Cambridge, M..." with entities "[(97, 106, 'SKILL'), (127, 137, 'SKILL'), (166, 16...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "    CURRICULUM VITAE
# IRSHAD
# Ashok Vihar Loni Dehat..." with entities "[(4, 14, 'SKILL'), (95, 100, 'SKILL'), (101, 104, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# MUNYASIA MAGRINE NANJALA
# Tel: 0..." with entities "[(0, 10, 'SKILL'), (69, 81, 'SKILL'), (117, 124, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mahir Mohammed Al Falahi
# North Al Hail, Muscat, Om..." with entities "[(53, 58, 'SKILL'), (73, 78, 'SKILL'), (95, 100, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VICTOR MAINGI MURUNGA
# P.O. BOX 388
# CHWELE
# TEL 0729..." with entities "[(27, 30, 'SKILL'), (69, 74, 'SKILL'), (90, 95, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "           CURRICULUM VITAE
# Name: MANAL MOHAMED AM..." with entities "[(11, 21, 'SKILL'), (87, 92, 'SKILL'), (93, 96, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MARIA CHRISTINE METZGER
# 540 Memorial Drive, #1008..." with entities "[(0, 5, 'SKILL'), (38, 43, 'SKILL'), (111, 120, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MARIO D. LEWIS
# 466 Cambridge Street
# Cambridge, MA..." with entities "[(83, 92, 'SKILL'), (110, 119, 'SKILL'), (151, 161...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CRAIG C. McKIRGAN, DO
#
#  Curriculum Vitae
#
# Prof..." with entities "[(6, 7, 'SKILL'), (26, 36, 'SKILL'), (46, 58, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "    JOB APPLIED FOR HR AND ADMIN
#  OR LOGISTIC OPER..." with entities "[(20, 22, 'SKILL'), (27, 32, 'SKILL'), (46, 55, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(

# %%
for epoch in range(50):
    losses = {}
    for text, annotations in TRAIN_DATA:
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, annotations)
        nlp.update([example], losses=losses)
    print(f"Epoch {epoch} Losses: {losses}")
# Out:
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Yogesh Chandra Pandey Mobile: +91--7017692645
# Mobi..." with entities "[(22, 28, 'SKILL'), (103, 106, 'SKILL'), (142, 153...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ARUN KUMAR U.C.
#
# Mob :+91 9745004628         Em..." with entities "[(13, 14, 'SKILL'), (48, 53, 'SKILL'), (65, 67, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ATHULIA GOPI
# KottalilThoppil (H)
# Chumathra P athul..." with entities "[(61, 66, 'SKILL'), (67, 70, 'SKILL'), (83, 85, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Attila László Joó, PhD
# External advisor
# PhD Civil ..." with entities "[(19, 22, 'SKILL'), (32, 39, 'SKILL'), (50, 58, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
#
# Barbara Farman,  Hair, Makeup and Groo..." with entities "[(74, 77, 'SKILL'), (372, 379, 'SKILL'), (443, 447...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# 2632  La Cienega Avenue      Los Angeles, Califo..." with entities "[(102, 105, 'SKILL'), (545, 550, 'SKILL'), (802, 8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Bethany Newell, Manicurist
# www.cloutierre..." with entities "[(54, 57, 'SKILL'), (805, 811, 'SKILL'), (834, 839...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Bic Owen , Wardrobe Stylist
# www.cloutierremix.com..." with entities "[(47, 50, 'SKILL'), (174, 185, 'SKILL'), (207, 214...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Graphic & Web DesignerBince George Erattayanickal ..." with entities "[(10, 13, 'SKILL'), (94, 97, 'SKILL'), (129, 134, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "  DR.SANTOSH KAKADE
#                             ..." with entities "[(210, 212, 'SKILL'), (214, 221, 'SKILL'), (242, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text " BIOGRAPHY   Dr. Kunal Aneja M.B.B.S., M.S. (Ortho..." with entities "[(29, 30, 'SKILL'), (71, 78, 'SKILL'), (90, 91, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "aa PASSPORT NO-M0824097              Z
#  CURRICULAM..." with entities "[(0, 2, 'SKILL'), (3, 11, 'SKILL'), (161, 166, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#  Carla Kay , Manicurist
# www.cloutierremix.c..." with entities "[(49, 52, 'SKILL'), (488, 492, 'SKILL'), (555, 560...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
#
# Carlos Ortiz,  Hairstylist
# www.clouti..." with entities "[(58, 61, 'SKILL'), (221, 225, 'SKILL'), (903, 905...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# 2632  La Cienega Avenue      Los Angeles, Califo..." with entities "[(102, 105, 'SKILL'), (207, 212, 'SKILL'), (493, 4...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# 2632  La Cienega Avenue      Los Angeles, Cali..." with entities "[(104, 107, 'SKILL'), (224, 231, 'SKILL'), (561, 5...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
# Chantal Moore,  Makeup Artist & Men’s Gr..." with entities "[(76, 79, 'SKILL'), (219, 223, 'SKILL'), (375, 379...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Charles McNair,  Hairstylist
# www.cloutierremix.co..." with entities "[(0, 7, 'SKILL'), (48, 51, 'SKILL'), (211, 219, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Cheryl Calo,  Hairstylist and Makeup Artis..." with entities "[(71, 74, 'SKILL'), (278, 279, 'SKILL'), (531, 534...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
#           NAMECHIRAG (First Name)..." with entities "[(0, 10, 'SKILL'), (128, 136, 'SKILL'), (151, 162,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
#
# Christophe Saluzzo, Hairstylist
# www.c..." with entities "[(63, 66, 'SKILL'), (407, 414, 'SKILL'), (645, 647...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
# Claudia Alonso,  Wardrobe Stylist
# www.c..." with entities "[(63, 66, 'SKILL'), (231, 237, 'SKILL'), (449, 455...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# SURES..." with entities "[(109, 114, 'SKILL'), (129, 134, 'SKILL'), (135, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Collier Strong,  Makeup Artist
# www.clouti..." with entities "[(58, 61, 'SKILL'), (498, 502, 'SKILL'), (1033, 10...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ALEX LUDIGA
# P.O BOX 75645-00200
# NAIROBI 0713789462..." with entities "[(16, 19, 'SKILL'), (62, 67, 'SKILL'), (68, 71, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "345 W. Fullerton Pkwy. #2101
# Chicago, IL 60614-285..." with entities "[(109, 118, 'SKILL'), (158, 164, 'SKILL'), (170, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULAM VITAE
# AIM   :        To achieve good sk..." with entities "[(35, 42, 'SKILL'), (48, 53, 'SKILL'), (113, 119, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "STEPHEN KARANJA NJOROGE,
# P.O Box 16461, 20100 Naku..." with entities "[(29, 32, 'SKILL'), (54, 59, 'SKILL'), (79, 84, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text " 1
#
#  CURRICULUM VITAE
#
# Prof.  Vinod Kumar PA..." with entities "[(8, 18, 'SKILL'), (137, 144, 'SKILL'), (173, 183,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Juan Antonio Aguilar Garib
# Curriculum Vitae
# Fecha:..." with entities "[(27, 37, 'SKILL'), (214, 216, 'SKILL'), (246, 250...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Juan Antonio Aguilar Garib
# Curriculum Vitae
# Fecha:..." with entities "[(27, 37, 'SKILL'), (178, 180, 'SKILL'), (526, 534...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Juan Antonio Aguilar-Garib
# Resume
# Date: January 20..." with entities "[(27, 33, 'SKILL'), (77, 79, 'SKILL'), (114, 123, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SATYAM RICHHARIYA
# Contact No. +918375887854
# E-mail..." with entities "[(61, 66, 'SKILL'), (67, 70, 'SKILL'), (108, 120, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Abdulla RS
# #18-15/1, MM Temple St, Old Pet,..." with entities "[(0, 6, 'SKILL'), (28, 30, 'SKILL'), (64, 66, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Bio-data
# Name Merrnosh Ichhaporria
# Date of Birth 1..." with entities "[(4, 8, 'SKILL'), (65, 79, 'SKILL'), (86, 95, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CHETAN SONI
# B.Tech (Hons.) Mechanical Engineering
# ..." with entities "[(14, 18, 'SKILL'), (27, 37, 'SKILL'), (38, 49, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "BIO DATA
# Personal Details
# Name :DIGVIJAY
# Father’s ..." with entities "[(4, 8, 'SKILL'), (9, 17, 'SKILL'), (178, 187, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text " Yuvraj Balu Dagade
#   Email Id:dagadeyuvraj19@gma..." with entities "[(23, 28, 'SKILL'), (47, 52, 'SKILL'), (53, 56, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "T e r r y     Ku n y
# CURRICULUM     VITÆ
# 240  ..." with entities "[(4, 5, 'SKILL'), (23, 33, 'SKILL'), (183, 191, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Toni P. Robinson, M.S., J.D.
# 100 Memorial Drive, #..." with entities "[(18, 19, 'SKILL'), (42, 47, 'SKILL'), (111, 117, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "C. Anthony Palumbo
# 19 Garden St, Apt 28
# Cambridge,..." with entities "[(0, 1, 'SKILL'), (88, 95, 'SKILL'), (118, 131, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "HARSH SHARMA
# H.NO.59, R.K.Puram
# Gali no:2A near Se..." with entities "[(22, 23, 'SKILL'), (48, 51, 'SKILL'), (94, 99, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VINEET	MATHRADAS		Way	No.	3023,	House	No.	1918	PO	..." with entities "[(47, 49, 'SKILL'), (50, 53, 'SKILL'), (58, 60, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                         RESUME
# Name:            ..." with entities "[(25, 31, 'SKILL'), (118, 122, 'SKILL'), (189, 199...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VIRAK V GANDHI
# Bhatiya Chakla, Gandhi Street, Mund..." with entities "[(163, 168, 'SKILL'), (183, 188, 'SKILL'), (189, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VRINDA VISWAMBHARAN
# korumbooru(H), Mudakuzha(PO), ..." with entities "[(45, 47, 'SKILL'), (94, 99, 'SKILL'), (100, 103, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                  «  Curriculum Vi..." with entities "[(37, 47, 'SKILL'), (217, 223, 'SKILL'), (255, 260...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURICULUM VITAE
# PERSONAL DETAILS
# NAME:  Nick Wamw..." with entities "[(17, 25, 'SKILL'), (114, 119, 'SKILL'), (154, 159...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "WENDY B. MILLER
# 6 Phillips St. #4
# Boston, MA 0211..." with entities "[(35, 41, 'SKILL'), (84, 93, 'SKILL'), (128, 138, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "WILLIAM CHU
# 295 Harvard Street #601
# Cambridge, MA ..." with entities "[(111, 121, 'SKILL'), (142, 145, 'SKILL'), (178, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Yukihiro WADA
# 69 Holland St., Apt. #A, Somerville,..." with entities "[(66, 69, 'SKILL'), (110, 117, 'SKILL'), (120, 128...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
#
#      ABIN JOY
# Contact No:
# +919846460616..." with entities "[(0, 6, 'SKILL'), (82, 87, 'SKILL'), (106, 109, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Md. Shaiyad Hussain
# Plot#151 & 152, Aali vi..." with entities "[(0, 6, 'SKILL'), (114, 119, 'SKILL'), (136, 139, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Page | 1CURRICULUM VITAE
# WANGILA Abraham Masinde
# E..." with entities "[(49, 54, 'SKILL'), (71, 76, 'SKILL'), (77, 80, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To work with an organization where my learning and..." with entities "[(3, 7, 'SKILL'), (16, 28, 'SKILL'), (38, 46, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ákos Pohl
# Chief Executive Manager
# MSC in Civil Eng..." with entities "[(26, 33, 'SKILL'), (34, 37, 'SKILL'), (41, 58, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Amber Dreadon,  Makeup Artist
# www.cloutie..." with entities "[(57, 60, 'SKILL'), (532, 536, 'SKILL'), (614, 619...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Anju Sasi
# Chempilakkal  (H) Kanjar P.O
# Idukk..." with entities "[(98, 103, 'SKILL'), (104, 107, 'SKILL'), (157, 17...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ANJU THOMAS ANNAMMA
# E-mail: anjuthomas2296@gmail.c..." with entities "[(43, 48, 'SKILL'), (49, 52, 'SKILL'), (53, 58, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Curriculum Vitae (CV)
# Kaviyarajan Kannan,
# 13/3009-..." with entities "[(0, 10, 'SKILL'), (18, 20, 'SKILL'), (115, 120, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
# Anna Lyles , Hairstylist
# www.cloutierremi..." with entities "[(52, 55, 'SKILL'), (199, 205, 'SKILL'), (516, 527...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# CAREER OBJECTIVE
# To work in a firm with a p..." with entities "[(0, 6, 'SKILL'), (27, 31, 'SKILL'), (49, 61, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#  April Chaney,  Hairstylist and Makeup Arti..." with entities "[(73, 76, 'SKILL'), (617, 625, 'SKILL'), (724, 730...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Archana Nair A
# Aiswarya House, Manjinikkara
# Omallo..." with entities "[(81, 86, 'SKILL'), (117, 122, 'SKILL'), (139, 144...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# NISHANT ..." with entities "[(231, 237, 'SKILL'), (254, 259, 'SKILL'), (275, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
#                                            ..." with entities "[(0, 6, 'SKILL'), (542, 547, 'SKILL'), (548, 551, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "KARTHIK THIRUMALASETTY
# Hs.no:12-5-3 green house, m..." with entities "[(23, 25, 'SKILL'), (36, 41, 'SKILL'), (82, 87, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Page 1 of 4
#  SAMER ADI
# Oman – Mobile:  00968 997..." with entities "[(32, 38, 'SKILL'), (76, 79, 'SKILL'), (89, 97, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# Sana Junaid
# Address: Villa no 672..." with entities "[(0, 10, 'SKILL'), (105, 116, 'SKILL'), (121, 133,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Curriculum     Vitae
# Kokula.Bhanuchander
# Mechan..." with entities "[(0, 10, 'SKILL'), (44, 54, 'SKILL'), (55, 63, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                                  ..." with entities "[(149, 155, 'SKILL'), (189, 194, 'SKILL'), (209, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
#     SARIKA SREEJITH                        ..." with entities "[(0, 6, 'SKILL'), (75, 80, 'SKILL'), (99, 104, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Shabina P
# Email: shabi0208@yahoo.co.in
# Phone: +9..." with entities "[(11, 16, 'SKILL'), (41, 46, 'SKILL'), (80, 87, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Shajudheen N
#     Sohar ,Oman
#     E mail–  nshaju..." with entities "[(56, 61, 'SKILL'), (62, 65, 'SKILL'), (70, 71, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHAMEEL IQBAL
# Apartment No. 02, Anjum Mansion,
# A.M..." with entities "[(49, 50, 'SKILL'), (136, 141, 'SKILL'), (156, 159...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Curriculum Vitae
# JAGADEESHA SHETTY, MD
# 1265 Wa..." with entities "[(2, 12, 'SKILL'), (66, 78, 'SKILL'), (117, 123, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# SHYAMA C
# PO BOX 1153
# Muttrah
# PC 114
# ..." with entities "[(21, 22, 'SKILL'), (23, 25, 'SKILL'), (26, 29, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "S
# INGARAVELU
# .B
# Email:
# singaravelued@gmail.com
# Fin..." with entities "[(16, 21, 'SKILL'), (37, 42, 'SKILL'), (43, 46, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CVCV
# Saud Ali Habib AL-Jardani
# Personal Statement
# ..." with entities "[(31, 39, 'SKILL'), (61, 70, 'SKILL'), (77, 86, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# AMANDEEP SINGH
# Electrical Engineer       ..." with entities "[(0, 6, 'SKILL'), (24, 34, 'SKILL'), (35, 43, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "W. A. Sullivan CV 1 Walter A. (Bill) Sullivan Depa..." with entities "[(15, 17, 'SKILL'), (46, 56, 'SKILL'), (60, 67, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SUNIL PAWAR
# Professional Qualification :
# B.B.A (B..." with entities "[(12, 24, 'SKILL'), (25, 38, 'SKILL'), (49, 69, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#                                              RES..." with entities "[(47, 53, 'SKILL'), (391, 395, 'SKILL'), (426, 431...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# SWAPNA .C.S
# Mobile: +971 54 7197274, +971 52 48..." with entities "[(10, 11, 'SKILL'), (15, 21, 'SKILL'), (101, 106, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Lawrence Swift
# 1234  My Drive, Huntington Beach,..." with entities "[(9, 14, 'SKILL'), (26, 31, 'SKILL'), (148, 153, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                   CURRICULUM VITAE
# ADDRESS       ..." with entities "[(19, 29, 'SKILL'), (172, 177, 'SKILL'), (178, 181...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#  RE S Ü M E E
#
# Erfahrener Allround Manager ..." with entities "[(12, 13, 'SKILL'), (42, 49, 'SKILL'), (191, 201, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#  R E S U M É
#
# Bred ledelsesmæssig erfaring..." with entities "[(5, 6, 'SKILL'), (13, 14, 'SKILL'), (253, 258, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Arockia Juslin Deepan
# Dubai, UAE
# Mobile: 97155805..." with entities "[(34, 40, 'SKILL'), (55, 60, 'SKILL'), (76, 81, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#  SU M M A R Y
#
# Experienced senior executive..." with entities "[(8, 9, 'SKILL'), (14, 15, 'SKILL'), (34, 40, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "TAMARA B. CHARM
# 358 Washington Street, Apt.1
# Some..." with entities "[(10, 15, 'SKILL'), (97, 106, 'SKILL'), (141, 151,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Tamas Futo
# Executive Civil engineer
# MSC in Ci..." with entities "[(32, 40, 'SKILL'), (41, 44, 'SKILL'), (48, 65, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                                  ..." with entities "[(123, 128, 'SKILL'), (129, 132, 'SKILL'), (260, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                      CURRICULUM VITAE
# MD.KAREEMUD..." with entities "[(22, 32, 'SKILL'), (86, 92, 'SKILL'), (138, 141, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Terry Kuny
#  CURRICULUM VITÆ
#  240 Fairmont Ave,..." with entities "[(14, 24, 'SKILL'), (105, 110, 'SKILL'), (111, 114...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Oniel Conroy Campbell
# 26 Shakespeare Avenue, Duhan..." with entities "[(53, 57, 'SKILL'), (101, 104, 'SKILL'), (131, 149...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "DEEPIKA KAUSHIK Contact No.: +91 9871904629 (M)
#   ..." with entities "[(45, 46, 'SKILL'), (190, 195, 'SKILL'), (215, 220...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ANU HARI BHARDWAJ
#
# Mobile: 07043030903       Tel ..." with entities "[(20, 26, 'SKILL'), (103, 106, 'SKILL'), (119, 131...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Resume
# PersonalDetails:- RAAKESH.S.MAHADIK.
#  -----..." with entities "[(0, 6, 'SKILL'), (251, 257, 'SKILL'), (301, 312, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PROFILE
# A data science professional with 1 years o..." with entities "[(10, 14, 'SKILL'), (15, 22, 'SKILL'), (23, 35, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#   CURRICULUM
# Arjun pandey
# House no. 135 sa..." with entities "[(9, 19, 'SKILL'), (93, 99, 'SKILL'), (154, 159, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MOHAMED  SHAHID
# Email: mshahid..." with entities "[(36, 41, 'SKILL'), (56, 61, 'SKILL'), (62, 65, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# CA. SONA  A. DEVASSY,  B.Com, ACA..." with entities "[(0, 10, 'SKILL'), (42, 45, 'SKILL'), (47, 50, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ALI NASSRULLAH  ALI ALOOSH
# Email: alialoosh012@gma..." with entities "[(27, 32, 'SKILL'), (47, 52, 'SKILL'), (53, 56, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Md. MijanurRahman
# Mobile: 008801779427505
# E-Mail: ..." with entities "[(18, 24, 'SKILL'), (64, 67, 'SKILL'), (75, 85, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Name: Marwa Dawood Hassan Alzadjali
# Email: marawi..." with entities "[(37, 42, 'SKILL'), (61, 64, 'SKILL'), (84, 89, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Dheeraj S. Sharma
# Date of Birth: 29th May, 1983.  ..." with entities "[(161, 166, 'SKILL'), (167, 170, 'SKILL'), (285, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
#                            ..." with entities "[(0, 10, 'SKILL'), (183, 194, 'SKILL'), (224, 230,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# ...
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Premananda Das
# B-131, New Ashok Nagar, New ..." with entities "[(0, 6, 'SKILL'), (85, 88, 'SKILL'), (89, 94, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE:
# Mr. Fredrick Hezekiah Owino Oden..." with entities "[(0, 10, 'SKILL'), (53, 58, 'SKILL'), (68, 73, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RAFIK MICHAEL WARD
# 143 Albany Street - Apt. 221B
# ..." with entities "[(105, 114, 'SKILL'), (144, 154, 'SKILL'), (183, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "UBAIS.T
# Falaj Al-Qabael
# Sohar
# Sultanate of Oman
# D..." with entities "[(64, 71, 'SKILL'), (87, 95, 'SKILL'), (174, 185, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Elke Naumburg Resume
#  1NAME ELKE NAUMBURG
# TITL..." with entities "[(14, 20, 'SKILL'), (78, 88, 'SKILL'), (89, 92, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# PHILLIP R. GOETZE
# goetze@glorietageo.com
#
# T..." with entities "[(12, 13, 'SKILL'), (42, 45, 'SKILL'), (70, 91, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "REDDY GANTA
# Environmental Scientist
#
# GLORIET..." with entities "[(14, 27, 'SKILL'), (28, 37, 'SKILL'), (52, 62, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "REDDY GANTA
# Agricultural Infomatics Scientist
# GLOR..." with entities "[(36, 45, 'SKILL'), (55, 65, 'SKILL'), (67, 70, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sagar Talreja
# B2/39 Ashok Vihar Phase 2, New Delhi..." with entities "[(82, 87, 'SKILL'), (102, 107, 'SKILL'), (108, 111...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Resume
# Dinesh Madhavan Nair, 402, Family Pharmacy ..." with entities "[(0, 6, 'SKILL'), (41, 49, 'SKILL'), (50, 58, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "KIRAN SHIVAPOOJI
# Address: At: Bachanal
# Post: Rajan..." with entities "[(121, 126, 'SKILL'), (127, 130, 'SKILL'), (160, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NIGITHA XAVIER
# Anjiparambil House
# Elamakkara P.O
# V..." with entities "[(123, 128, 'SKILL'), (142, 147, 'SKILL'), (148, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                        A.MOHAMMED FAZIL          ..." with entities "[(78, 83, 'SKILL'), (84, 87, 'SKILL'), (113, 122, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cheat Sheet www.mapdb.org
# Maven
# <dependency>
#     <..." with entities "[(26, 31, 'SKILL'), (33, 43, 'SKILL'), (226, 234, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Sanafathima Sayyed
# #Third Cross Road, Patel..." with entities "[(0, 6, 'SKILL'), (60, 66, 'SKILL'), (129, 134, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# HEMANT GANGWAR
# +91 9891621755
# WZ 694 Narain..." with entities "[(0, 6, 'SKILL'), (106, 111, 'SKILL'), (112, 115, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Séminaire Qualité de l’air et santé de l’enfant – ..." with entities "[(1336, 1339, 'SKILL'), (1580, 1583, 'SKILL'), (15...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# CURR..." with entities "[(46, 56, 'SKILL'), (107, 113, 'SKILL'), (182, 187...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# MOHD SHADAB
# Address:59/71-B, Paka..." with entities "[(0, 10, 'SKILL'), (105, 111, 'SKILL'), (151, 156,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MUHAMMAD IQBAL HOSSAIN
# Mobile : 0096894864966
# e-..." with entities "[(24, 30, 'SKILL'), (71, 76, 'SKILL'), (77, 80, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J. MADISON ILER
# 143 Albany St. #313A
# Cambridge, M..." with entities "[(97, 106, 'SKILL'), (127, 137, 'SKILL'), (166, 16...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "    CURRICULUM VITAE
# IRSHAD
# Ashok Vihar Loni Dehat..." with entities "[(4, 14, 'SKILL'), (95, 100, 'SKILL'), (101, 104, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# MUNYASIA MAGRINE NANJALA
# Tel: 0..." with entities "[(0, 10, 'SKILL'), (69, 81, 'SKILL'), (117, 124, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mahir Mohammed Al Falahi
# North Al Hail, Muscat, Om..." with entities "[(53, 58, 'SKILL'), (73, 78, 'SKILL'), (95, 100, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VICTOR MAINGI MURUNGA
# P.O. BOX 388
# CHWELE
# TEL 0729..." with entities "[(27, 30, 'SKILL'), (69, 74, 'SKILL'), (90, 95, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "           CURRICULUM VITAE
# Name: MANAL MOHAMED AM..." with entities "[(11, 21, 'SKILL'), (87, 92, 'SKILL'), (93, 96, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MARIA CHRISTINE METZGER
# 540 Memorial Drive, #1008..." with entities "[(0, 5, 'SKILL'), (38, 43, 'SKILL'), (111, 120, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MARIO D. LEWIS
# 466 Cambridge Street
# Cambridge, MA..." with entities "[(83, 92, 'SKILL'), (110, 119, 'SKILL'), (151, 161...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CRAIG C. McKIRGAN, DO
#
#  Curriculum Vitae
#
# Prof..." with entities "[(6, 7, 'SKILL'), (26, 36, 'SKILL'), (46, 58, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "    JOB APPLIED FOR HR AND ADMIN
#  OR LOGISTIC OPER..." with entities "[(20, 22, 'SKILL'), (27, 32, 'SKILL'), (46, 55, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Epoch 0 Losses: {'ner': np.float32(29979.775)}
# Epoch 1 Losses: {'ner': np.float32(21800.951)}
# Epoch 2 Losses: {'ner': np.float32(17716.223)}
# Epoch 3 Losses: {'ner': np.float32(15452.748)}
# Epoch 4 Losses: {'ner': np.float32(14299.281)}
# Epoch 5 Losses: {'ner': np.float32(12661.549)}
# Epoch 6 Losses: {'ner': np.float32(10938.656)}
# Epoch 7 Losses: {'ner': np.float32(9293.594)}
# Epoch 8 Losses: {'ner': np.float32(8878.378)}
# Epoch 9 Losses: {'ner': np.float32(9317.594)}
# Epoch 10 Losses: {'ner': np.float32(8212.956)}
# Epoch 11 Losses: {'ner': np.float32(6846.665)}
# Epoch 12 Losses: {'ner': np.float32(6175.6597)}
# Epoch 13 Losses: {'ner': np.float32(6014.437)}
# Epoch 14 Losses: {'ner': np.float32(6052.439)}
# Epoch 15 Losses: {'ner': np.float32(5245.294)}
# Epoch 16 Losses: {'ner': np.float32(4867.8164)}
# Epoch 17 Losses: {'ner': np.float32(4518.8335)}
# Epoch 18 Losses: {'ner': np.float32(4631.9946)}
# Epoch 19 Losses: {'ner': np.float32(4378.6606)}
# Epoch 20 Losses: {'ner': np.float32(4203.624)}
# Epoch 21 Losses: {'ner': np.float32(3968.069)}
# Epoch 22 Losses: {'ner': np.float32(3802.737)}
# Epoch 23 Losses: {'ner': np.float32(3586.5002)}
# Epoch 24 Losses: {'ner': np.float32(3385.5068)}
# Epoch 25 Losses: {'ner': np.float32(3221.84)}
# Epoch 26 Losses: {'ner': np.float32(3092.9478)}
# Epoch 27 Losses: {'ner': np.float32(3232.7566)}
# Epoch 28 Losses: {'ner': np.float32(3221.2478)}
# Epoch 29 Losses: {'ner': np.float32(2848.7876)}
# Epoch 30 Losses: {'ner': np.float32(2801.33)}
# Epoch 31 Losses: {'ner': np.float32(2951.4514)}
# Epoch 32 Losses: {'ner': np.float32(2576.316)}
# Epoch 33 Losses: {'ner': np.float32(2518.5073)}
# Epoch 34 Losses: {'ner': np.float32(2656.6182)}
# Epoch 35 Losses: {'ner': np.float32(2381.3364)}
# Epoch 36 Losses: {'ner': np.float32(2405.485)}
# Epoch 37 Losses: {'ner': np.float32(2886.822)}
# Epoch 38 Losses: {'ner': np.float32(2554.403)}
# Epoch 39 Losses: {'ner': np.float32(2597.0146)}
# Epoch 40 Losses: {'ner': np.float32(2217.6462)}
# Epoch 41 Losses: {'ner': np.float32(2235.2585)}
# Epoch 42 Losses: {'ner': np.float32(2386.153)}
# Epoch 43 Losses: {'ner': np.float32(2169.0767)}
# Epoch 44 Losses: {'ner': np.float32(2111.508)}
# Epoch 45 Losses: {'ner': np.float32(2048.8357)}
# Epoch 46 Losses: {'ner': np.float32(2093.891)}
# Epoch 47 Losses: {'ner': np.float32(2040.241)}
# Epoch 48 Losses: {'ner': np.float32(1852.8523)}
# Epoch 49 Losses: {'ner': np.float32(1996.3304)}

# %%
from spacy.training.example import Example
from spacy.scorer import Scorer
import random

# Split data
random.shuffle(TRAIN_DATA)
split = int(len(TRAIN_DATA) * 0.8)
train_data = TRAIN_DATA[:split]
valid_data = TRAIN_DATA[split:]

# %%
from spacy.training import offsets_to_biluo_tags, Example
misaligned = []
for text, entities in TRAIN_DATA:
    doc = nlp.make_doc(text)
    try:
        offsets_to_biluo_tags(doc, entities)
    except ValueError:
        misaligned.append((text, entities))
print(f"Number of misaligned entries: {len(misaligned)}")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[28], line 4
#       2 misaligned = []
#       3 for text, entities in TRAIN_DATA:
# ----> 4     doc = nlp.make_doc(text)
#       5     try:
#       6         offsets_to_biluo_tags(doc, entities)
#
# File ~\anaconda3\Lib\site-packages\spacy\language.py:1124, in Language.make_doc(self, text)
#    1120 if len(text) > self.max_length:
#    1121     raise ValueError(
#    1122         Errors.E088.format(length=len(text), max_length=self.max_length)
#    1123     )
# -> 1124 return self.tokenizer(text)
#
# File ~\anaconda3\Lib\site-packages\spacy\tokenizer.pyx:160, in spacy.tokenizer.Tokenizer.__call__()
#
# File ~\anaconda3\Lib\site-packages\spacy\tokenizer.pyx:194, in spacy.tokenizer.Tokenizer._tokenize_affixes()
#
# File ~\anaconda3\Lib\site-packages\spacy\strings.pyx:63, in spacy.strings.hash_string()
#
# UnicodeEncodeError: 'utf-8' codec can't encode character '\ud83d' in position 0: surrogates not allowed

# %%
from spacy.training.example import Example
from spacy.scorer import Scorer

# Create validation examples
valid_examples = [Example.from_dict(nlp.make_doc(text), annotations) for text, annotations in valid_data]

# Score all examples at once
scorer = Scorer()
scores = scorer.score(valid_examples)

print(f"Epoch {epoch} Validation scores:", scores)
# Out:
# Epoch 0 Validation scores: {'token_acc': None, 'token_p': None, 'token_r': None, 'token_f': None, 'sents_p': None, 'sents_r': None, 'sents_f': None, 'tag_acc': None, 'pos_acc': None, 'morph_acc': None, 'morph_micro_p': None, 'morph_micro_r': None, 'morph_micro_f': None, 'morph_per_feat': None, 'dep_uas': None, 'dep_las': None, 'dep_las_per_type': None, 'ents_p': None, 'ents_r': None, 'ents_f': None, 'ents_per_type': None, 'cats_score': 0.0, 'cats_score_desc': 'macro F', 'cats_micro_p': 0.0, 'cats_micro_r': 0.0, 'cats_micro_f': 0.0, 'cats_macro_p': 0.0, 'cats_macro_r': 0.0, 'cats_macro_f': 0.0, 'cats_macro_auc': 0.0, 'cats_f_per_type': {}, 'cats_auc_per_type': {}}

# %%
for epoch in range(50):
    random.shuffle(train_data)
    losses = {}
    
    # Training
    for text, annotations in train_data:
        doc = nlp.make_doc(text)
        example = Example.from_dict(doc, annotations)
        nlp.update([example], drop=0.3, losses=losses)
    
    print(f"Epoch {epoch} Training Losses: {losses}")
    
    # Validation
    scorer = Scorer()
    for text, annotations in valid_data:
        doc = nlp(text)
        example = Example.from_dict(doc, annotations)
        scorer.score(example)
    
    print(f"Epoch {epoch} Validation scores:", scorer.scores)
# Out:
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Resume
# Dinesh Madhavan Nair, 402, Family Pharmacy ..." with entities "[(0, 6, 'SKILL'), (41, 49, 'SKILL'), (50, 58, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# KULDEEP CHANDRAKANT  BHAGWAT
# Geeta Narayan ..." with entities "[(0, 6, 'SKILL'), (82, 86, 'SKILL'), (108, 114, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MOHANRAJ THANGARAJ
#  D-Wing/301, Green Gagan Buildi..." with entities "[(32, 37, 'SKILL'), (44, 52, 'SKILL'), (120, 126, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cheat Sheet www.mapdb.org
# Maven
# <dependency>
#     <..." with entities "[(26, 31, 'SKILL'), (33, 43, 'SKILL'), (226, 234, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# AMANDEEP SINGH
# Electrical Engineer       ..." with entities "[(0, 6, 'SKILL'), (24, 34, 'SKILL'), (35, 43, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
#
# Barbara Farman,  Hair, Makeup and Groo..." with entities "[(74, 77, 'SKILL'), (372, 379, 'SKILL'), (443, 447...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Md. MijanurRahman
# Mobile: 008801779427505
# E-Mail: ..." with entities "[(18, 24, 'SKILL'), (64, 67, 'SKILL'), (75, 85, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# CAREER OBJECTIVE
# To work in a firm with a p..." with entities "[(0, 6, 'SKILL'), (27, 31, 'SKILL'), (49, 61, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MARIA CHRISTINE METZGER
# 540 Memorial Drive, #1008..." with entities "[(0, 5, 'SKILL'), (38, 43, 'SKILL'), (111, 120, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                         RESUME
# Name:            ..." with entities "[(25, 31, 'SKILL'), (118, 122, 'SKILL'), (189, 199...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NIGITHA XAVIER
# Anjiparambil House
# Elamakkara P.O
# V..." with entities "[(123, 128, 'SKILL'), (142, 147, 'SKILL'), (148, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURICULLUMVITAE
# AFTAB AHMAD
# S/o Mr.Sarfaraz Ahmad
# ..." with entities "[(138, 143, 'SKILL'), (159, 164, 'SKILL'), (165, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "WILLIAM CHU
# 295 Harvard Street #601
# Cambridge, MA ..." with entities "[(111, 121, 'SKILL'), (142, 145, 'SKILL'), (178, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# TANVEER ALAM
# Phone: (M) +91 7042165152,  Em..." with entities "[(20, 25, 'SKILL'), (28, 29, 'SKILL'), (48, 53, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "N. Suresh
# # AL – 202, Door No: F4, Santosh Apartm..." with entities "[(101, 106, 'SKILL'), (120, 125, 'SKILL'), (126, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CVCV
# Saud Ali Habib AL-Jardani
# Personal Statement
# ..." with entities "[(31, 39, 'SKILL'), (61, 70, 'SKILL'), (77, 86, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Shajudheen N
#     Sohar ,Oman
#     E mail–  nshaju..." with entities "[(56, 61, 'SKILL'), (62, 65, 'SKILL'), (70, 71, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text " 1
#
#  CURRICULUM VITAE
#
# Prof.  Vinod Kumar PA..." with entities "[(8, 18, 'SKILL'), (137, 144, 'SKILL'), (173, 183,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ANJU THOMAS ANNAMMA
# E-mail: anjuthomas2296@gmail.c..." with entities "[(43, 48, 'SKILL'), (49, 52, 'SKILL'), (53, 58, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Bio-data
# Name Merrnosh Ichhaporria
# Date of Birth 1..." with entities "[(4, 8, 'SKILL'), (65, 79, 'SKILL'), (86, 95, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
# Anna Lyles , Hairstylist
# www.cloutierremi..." with entities "[(52, 55, 'SKILL'), (199, 205, 'SKILL'), (516, 527...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Tamas Futo
# Executive Civil engineer
# MSC in Ci..." with entities "[(32, 40, 'SKILL'), (41, 44, 'SKILL'), (48, 65, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Séminaire Qualité de l’air et santé de l’enfant – ..." with entities "[(1336, 1339, 'SKILL'), (1580, 1583, 'SKILL'), (15...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PAUL WANJALA WEKESA
# CURRICULUM VITAE
# PAUL WANJALA ..." with entities "[(20, 30, 'SKILL'), (80, 85, 'SKILL'), (86, 89, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VRINDA VISWAMBHARAN
# korumbooru(H), Mudakuzha(PO), ..." with entities "[(45, 47, 'SKILL'), (94, 99, 'SKILL'), (100, 103, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NOUFAL.S
# A
# highly
# innovative
# and
# competent
# softwar..." with entities "[(18, 28, 'SKILL'), (33, 42, 'SKILL'), (43, 51, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PROFILE
# A data science professional with 1 years o..." with entities "[(10, 14, 'SKILL'), (15, 22, 'SKILL'), (23, 35, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "C.V
# Name :MohammedIbrahimAhmedAkl
# Date&PlaceofBirt..." with entities "[(0, 1, 'SKILL'), (97, 108, 'SKILL'), (126, 131, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "REDDY GANTA
# Agricultural Infomatics Scientist
# GLOR..." with entities "[(36, 45, 'SKILL'), (55, 65, 'SKILL'), (67, 70, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SAMER ADI
# Oman – Mobile: 00968 99793231
# E-mail: sa..." with entities "[(17, 23, 'SKILL'), (66, 69, 'SKILL'), (70, 78, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#   8 8 8 8 Personnel Skills  N A V I N    D E S H..." with entities "[(12, 21, 'SKILL'), (22, 28, 'SKILL'), (100, 112, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ANU HARI BHARDWAJ
#
# Mobile: 07043030903       Tel ..." with entities "[(20, 26, 'SKILL'), (103, 106, 'SKILL'), (119, 131...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Page 1 of 4
#  SAMER ADI
# Oman – Mobile:  00968 997..." with entities "[(32, 38, 'SKILL'), (76, 79, 'SKILL'), (89, 97, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# 2632  La Cienega Avenue      Los Angeles, Cali..." with entities "[(104, 107, 'SKILL'), (224, 231, 'SKILL'), (561, 5...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Premananda Das
# B-131, New Ashok Nagar, New ..." with entities "[(0, 6, 'SKILL'), (85, 88, 'SKILL'), (89, 94, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Name: Marwa Dawood Hassan Alzadjali
# Email: marawi..." with entities "[(37, 42, 'SKILL'), (61, 64, 'SKILL'), (84, 89, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mahir Mohammed Al Falahi
# North Al Hail, Muscat, Om..." with entities "[(53, 58, 'SKILL'), (73, 78, 'SKILL'), (95, 100, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                  «  Curriculum Vi..." with entities "[(37, 47, 'SKILL'), (217, 223, 'SKILL'), (255, 260...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "To work with an organization where my learning and..." with entities "[(3, 7, 'SKILL'), (16, 28, 'SKILL'), (38, 46, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "1 - of - 5
#  Curriculum Vita
#
# Osama Abdulkhaliq..." with entities "[(13, 23, 'SKILL'), (93, 104, 'SKILL'), (119, 125,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Resume
# PersonalDetails:- RAAKESH.S.MAHADIK.
#  -----..." with entities "[(0, 6, 'SKILL'), (251, 257, 'SKILL'), (301, 312, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "TAMARA B. CHARM
# 358 Washington Street, Apt.1
# Some..." with entities "[(10, 15, 'SKILL'), (97, 106, 'SKILL'), (141, 151,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Curriculum Vitae   Saif Saleh AL -Aufi
#
# OBJECTI..." with entities "[(0, 10, 'SKILL'), (73, 82, 'SKILL'), (86, 96, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "REDDY GANTA
# Environmental Scientist
#
# GLORIET..." with entities "[(14, 27, 'SKILL'), (28, 37, 'SKILL'), (52, 62, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Shabina P
# Email: shabi0208@yahoo.co.in
# Phone: +9..." with entities "[(11, 16, 'SKILL'), (41, 46, 'SKILL'), (80, 87, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#                                              RES..." with entities "[(47, 53, 'SKILL'), (391, 395, 'SKILL'), (426, 431...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "S
# INGARAVELU
# .B
# Email:
# singaravelued@gmail.com
# Fin..." with entities "[(16, 21, 'SKILL'), (37, 42, 'SKILL'), (43, 46, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MOHAMED  SHAHID
# Email: mshahid..." with entities "[(36, 41, 'SKILL'), (56, 61, 'SKILL'), (62, 65, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Reetabrata Bhattacharya
# Date of Birth – 15 th  Ju..." with entities "[(92, 97, 'SKILL'), (105, 110, 'SKILL'), (132, 135...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Anju Sasi
# Chempilakkal  (H) Kanjar P.O
# Idukk..." with entities "[(98, 103, 'SKILL'), (104, 107, 'SKILL'), (157, 17...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# DETAILS
# MUSCAT, SULTANATE OF
# OMA..." with entities "[(0, 10, 'SKILL'), (81, 86, 'SKILL'), (87, 90, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "345 W. Fullerton Pkwy. #2101
# Chicago, IL 60614-285..." with entities "[(109, 118, 'SKILL'), (158, 164, 'SKILL'), (170, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
#           NAMECHIRAG (First Name)..." with entities "[(0, 10, 'SKILL'), (128, 136, 'SKILL'), (151, 162,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Cheryl Calo,  Hairstylist and Makeup Artis..." with entities "[(71, 74, 'SKILL'), (278, 279, 'SKILL'), (531, 534...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Juan Antonio Aguilar-Garib
# Resume
# Date: January 20..." with entities "[(27, 33, 'SKILL'), (77, 79, 'SKILL'), (114, 123, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# 2632  La Cienega Avenue      Los Angeles, Califo..." with entities "[(102, 105, 'SKILL'), (207, 212, 'SKILL'), (493, 4...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Curriculum     Vitae
# Kokula.Bhanuchander
# Mechan..." with entities "[(0, 10, 'SKILL'), (44, 54, 'SKILL'), (55, 63, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ARUN KUMAR U.C.
#
# Mob :+91 9745004628         Em..." with entities "[(13, 14, 'SKILL'), (48, 53, 'SKILL'), (65, 67, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                                  ..." with entities "[(123, 128, 'SKILL'), (129, 132, 'SKILL'), (260, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ROBAI N. KHAEMBA
# P.O. BOX 52637-00200
# Nairobi, ..." with entities "[(23, 26, 'SKILL'), (56, 62, 'SKILL'), (104, 109, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "KARTHIK THIRUMALASETTY
# Hs.no:12-5-3 green house, m..." with entities "[(23, 25, 'SKILL'), (36, 41, 'SKILL'), (82, 87, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "    JOB APPLIED FOR HR AND ADMIN
#  OR LOGISTIC OPER..." with entities "[(20, 22, 'SKILL'), (27, 32, 'SKILL'), (46, 55, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RAFIK MICHAEL WARD
# 143 Albany Street - Apt. 221B
# ..." with entities "[(105, 114, 'SKILL'), (144, 154, 'SKILL'), (183, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Yogesh Chandra Pandey Mobile: +91--7017692645
# Mobi..." with entities "[(22, 28, 'SKILL'), (103, 106, 'SKILL'), (142, 153...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# RRAAJJEESSHH  KKUUMMAARR
#
# : 63, Keshav Naga..." with entities "[(125, 130, 'SKILL'), (131, 134, 'SKILL'), (357, 3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Arockia Juslin Deepan
# Dubai, UAE
# Mobile: 97155805..." with entities "[(34, 40, 'SKILL'), (55, 60, 'SKILL'), (76, 81, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "           CURRICULUM VITAE
# Name: MANAL MOHAMED AM..." with entities "[(11, 21, 'SKILL'), (87, 92, 'SKILL'), (93, 96, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
# 2017  Al-Qurum, Madinat Al -Allam
# Muscat,..." with entities "[(85, 88, 'SKILL'), (148, 160, 'SKILL'), (170, 171...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "UBAIS.T
# Falaj Al-Qabael
# Sohar
# Sultanate of Oman
# D..." with entities "[(64, 71, 'SKILL'), (87, 95, 'SKILL'), (174, 185, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULAM VITAE
# AIM   :        To achieve good sk..." with entities "[(35, 42, 'SKILL'), (48, 53, 'SKILL'), (113, 119, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sagar Talreja
# B2/39 Ashok Vihar Phase 2, New Delhi..." with entities "[(82, 87, 'SKILL'), (102, 107, 'SKILL'), (108, 111...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MUHAMMAD SUMAIR ZUBAIR
# MOBILE  : +96892661345
#     ..." with entities "[(23, 29, 'SKILL'), (87, 92, 'SKILL'), (93, 96, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "HARSH SHARMA
# H.NO.59, R.K.Puram
# Gali no:2A near Se..." with entities "[(22, 23, 'SKILL'), (48, 51, 'SKILL'), (94, 99, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#  RE S Ü M E E
#
# Erfahrener Allround Manager ..." with entities "[(12, 13, 'SKILL'), (42, 49, 'SKILL'), (191, 201, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MUHAMMAD IQBAL HOSSAIN
# Mobile : 0096894864966
# e-..." with entities "[(24, 30, 'SKILL'), (71, 76, 'SKILL'), (77, 80, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
#                                            ..." with entities "[(0, 6, 'SKILL'), (542, 547, 'SKILL'), (548, 551, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                                  ..." with entities "[(62, 68, 'SKILL'), (368, 373, 'SKILL'), (374, 377...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SHAMEEL IQBAL
# Apartment No. 02, Anjum Mansion,
# A.M..." with entities "[(49, 50, 'SKILL'), (136, 141, 'SKILL'), (156, 159...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Abdulla RS
# #18-15/1, MM Temple St, Old Pet,..." with entities "[(0, 6, 'SKILL'), (28, 30, 'SKILL'), (64, 66, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MARIO D. LEWIS
# 466 Cambridge Street
# Cambridge, MA..." with entities "[(83, 92, 'SKILL'), (110, 119, 'SKILL'), (151, 161...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# Sana Junaid
# Address: Villa no 672..." with entities "[(0, 10, 'SKILL'), (105, 116, 'SKILL'), (121, 133,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
# Chantal Moore,  Makeup Artist & Men’s Gr..." with entities "[(76, 79, 'SKILL'), (219, 223, 'SKILL'), (375, 379...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Curriculum Vita ´e
# ChitaR. Das
# OfﬁceAddress: HomeA..." with entities "[(0, 10, 'SKILL'), (58, 68, 'SKILL'), (72, 80, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Juan Antonio Aguilar Garib
# Curriculum Vitae
# Fecha:..." with entities "[(27, 37, 'SKILL'), (178, 180, 'SKILL'), (526, 534...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "aa PASSPORT NO-M0824097              Z
#  CURRICULAM..." with entities "[(0, 2, 'SKILL'), (3, 11, 'SKILL'), (161, 166, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Bic Owen , Wardrobe Stylist
# www.cloutierremix.com..." with entities "[(47, 50, 'SKILL'), (174, 185, 'SKILL'), (207, 214...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text " Yuvraj Balu Dagade
#   Email Id:dagadeyuvraj19@gma..." with entities "[(23, 28, 'SKILL'), (47, 52, 'SKILL'), (53, 56, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# SURES..." with entities "[(109, 114, 'SKILL'), (129, 134, 'SKILL'), (135, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# MOHD SHADAB
# Address:59/71-B, Paka..." with entities "[(0, 10, 'SKILL'), (105, 111, 'SKILL'), (151, 156,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "STEPHEN KARANJA NJOROGE,
# P.O Box 16461, 20100 Naku..." with entities "[(29, 32, 'SKILL'), (54, 59, 'SKILL'), (79, 84, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ALEX LUDIGA
# P.O BOX 75645-00200
# NAIROBI 0713789462..." with entities "[(16, 19, 'SKILL'), (62, 67, 'SKILL'), (68, 71, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
#
# Carlos Ortiz,  Hairstylist
# www.clouti..." with entities "[(58, 61, 'SKILL'), (221, 225, 'SKILL'), (903, 905...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "KIRAN SHIVAPOOJI
# Address: At: Bachanal
# Post: Rajan..." with entities "[(121, 126, 'SKILL'), (127, 130, 'SKILL'), (160, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text " BIOGRAPHY   Dr. Kunal Aneja M.B.B.S., M.S. (Ortho..." with entities "[(29, 30, 'SKILL'), (71, 78, 'SKILL'), (90, 91, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Bethany Newell, Manicurist
# www.cloutierre..." with entities "[(54, 57, 'SKILL'), (805, 811, 'SKILL'), (834, 839...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Charles McNair,  Hairstylist
# www.cloutierremix.co..." with entities "[(0, 7, 'SKILL'), (48, 51, 'SKILL'), (211, 219, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# NISHANT ..." with entities "[(231, 237, 'SKILL'), (254, 259, 'SKILL'), (275, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ákos Pohl
# Chief Executive Manager
# MSC in Civil Eng..." with entities "[(26, 33, 'SKILL'), (34, 37, 'SKILL'), (41, 58, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Attila László Joó, PhD
# External advisor
# PhD Civil ..." with entities "[(19, 22, 'SKILL'), (32, 39, 'SKILL'), (50, 58, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#  R E S U M É
#
# Bred ledelsesmæssig erfaring..." with entities "[(5, 6, 'SKILL'), (13, 14, 'SKILL'), (253, 258, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# CA. SONA  A. DEVASSY,  B.Com, ACA..." with entities "[(0, 10, 'SKILL'), (42, 45, 'SKILL'), (47, 50, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# MUNYASIA MAGRINE NANJALA
# Tel: 0..." with entities "[(0, 10, 'SKILL'), (69, 81, 'SKILL'), (117, 124, '...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                                  ..." with entities "[(141, 149, 'SKILL'), (150, 161, 'SKILL'), (322, 3...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "W. A. Sullivan CV 1 Walter A. (Bill) Sullivan Depa..." with entities "[(15, 17, 'SKILL'), (46, 56, 'SKILL'), (60, 67, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# Mahendra Kumar Yogi
#
# Personal Details
# HR &Adm..." with entities "[(26, 34, 'SKILL'), (43, 45, 'SKILL'), (47, 52, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                      CURRICULUM VITAE
# MD.KAREEMUD..." with entities "[(22, 32, 'SKILL'), (86, 92, 'SKILL'), (138, 141, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURICULUM VITAE
# PERSONAL DETAILS
# NAME:  Nick Wamw..." with entities "[(17, 25, 'SKILL'), (114, 119, 'SKILL'), (154, 159...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "DEEPIKA KAUSHIK Contact No.: +91 9871904629 (M)
#   ..." with entities "[(45, 46, 'SKILL'), (190, 195, 'SKILL'), (215, 220...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
#
# ...
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
# CHONG MIN PARK, M.D.
# 22868 Ro..." with entities "[(0, 10, 'SKILL'), (29, 33, 'SKILL'), (35, 36, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VIRAK V GANDHI
# Bhatiya Chakla, Gandhi Street, Mund..." with entities "[(163, 168, 'SKILL'), (183, 188, 'SKILL'), (189, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUM VITAE
#                            ..." with entities "[(0, 10, 'SKILL'), (183, 194, 'SKILL'), (224, 230,...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CHETAN SONI
# B.Tech (Hons.) Mechanical Engineering
# ..." with entities "[(14, 18, 'SKILL'), (27, 37, 'SKILL'), (38, 49, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
# Collier Strong,  Makeup Artist
# www.clouti..." with entities "[(58, 61, 'SKILL'), (498, 502, 'SKILL'), (1033, 10...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Juan Antonio Aguilar Garib
# Curriculum Vitae
# Fecha:..." with entities "[(27, 37, 'SKILL'), (214, 216, 'SKILL'), (246, 250...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Robyn Goss
# Address .
# Phone Number
# Email addre..." with entities "[(24, 29, 'SKILL'), (39, 44, 'SKILL'), (93, 98, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Juan Antonio Aguilar Garib
# Curriculum Vitae
# Fecha:..." with entities "[(27, 37, 'SKILL'), (235, 237, 'SKILL'), (238, 242...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CRAIG C. McKIRGAN, DO
#
#  Curriculum Vitae
#
# Prof..." with entities "[(6, 7, 'SKILL'), (26, 36, 'SKILL'), (46, 58, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NEETHU SUSAN MATHEW
# Phone No:  +968 96135677 / 989..." with entities "[(20, 25, 'SKILL'), (78, 83, 'SKILL'), (84, 87, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Page | 1CURRICULUM VITAE
# WANGILA Abraham Masinde
# E..." with entities "[(49, 54, 'SKILL'), (71, 76, 'SKILL'), (77, 80, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Curriculum Viet
# Salama Said Al Habsi
# Contact Info
# ..." with entities "[(0, 10, 'SKILL'), (69, 74, 'SKILL'), (75, 78, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SUNIL PAWAR
# Professional Qualification :
# B.B.A (B..." with entities "[(12, 24, 'SKILL'), (25, 38, 'SKILL'), (49, 69, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# NAJMAL  MUSTAFA
# Call:  +96 87 93 93 888     ..." with entities "[(81, 83, 'SKILL'), (93, 97, 'SKILL'), (133, 139, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# Resume
#
#
#
#
# Shobhith Rai Budaloor
# Addres..." with entities "[(3, 9, 'SKILL'), (64, 71, 'SKILL'), (76, 87, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# CURR..." with entities "[(46, 56, 'SKILL'), (107, 113, 'SKILL'), (182, 187...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
#     SARIKA SREEJITH                        ..." with entities "[(0, 6, 'SKILL'), (75, 80, 'SKILL'), (99, 104, 'SK...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "                                   Curriculum Vita..." with entities "[(35, 45, 'SKILL'), (91, 94, 'SKILL'), (110, 114, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
# 2632  La Cienega Avenue      Los Angeles, Califo..." with entities "[(102, 105, 'SKILL'), (545, 550, 'SKILL'), (802, 8...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "VICTOR MAINGI MURUNGA
# P.O. BOX 388
# CHWELE
# TEL 0729..." with entities "[(27, 30, 'SKILL'), (69, 74, 'SKILL'), (90, 95, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CURRICULUMVITAE
# Career Objective                  ..." with entities "[(160, 169, 'SKILL'), (207, 213, 'SKILL'), (219, 2...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "SATYAM RICHHARIYA
# Contact No. +918375887854
# E-mail..." with entities "[(61, 66, 'SKILL'), (67, 70, 'SKILL'), (108, 120, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Oniel Conroy Campbell
# 26 Shakespeare Avenue, Duhan..." with entities "[(53, 57, 'SKILL'), (101, 104, 'SKILL'), (131, 149...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RAJESH KUMARRAJESH KUMAR
# : 63, Keshav Nagar, Pal ..." with entities "[(116, 121, 'SKILL'), (122, 125, 'SKILL'), (126, 1...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Elke Naumburg Resume
#  1NAME ELKE NAUMBURG
# TITL..." with entities "[(14, 20, 'SKILL'), (78, 88, 'SKILL'), (89, 92, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Yukihiro WADA
# 69 Holland St., Apt. #A, Somerville,..." with entities "[(66, 69, 'SKILL'), (110, 117, 'SKILL'), (120, 128...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RESUME
# Priya  Elza
# Jacob
# Phone: 0091-9995532188
# Em..." with entities "[(0, 6, 'SKILL'), (25, 30, 'SKILL'), (48, 53, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "RUSTOM FAIZ MUHAMMAD AL- RAIISI
# Contact No: +968-9..." with entities "[(94, 99, 'SKILL'), (100, 103, 'SKILL'), (137, 145...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#  SU M M A R Y
#
# Experienced senior executive..." with entities "[(8, 9, 'SKILL'), (14, 15, 'SKILL'), (34, 40, 'SKI...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "J. MADISON ILER
# 143 Albany St. #313A
# Cambridge, M..." with entities "[(97, 106, 'SKILL'), (127, 137, 'SKILL'), (166, 16...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "WENDY B. MILLER
# 6 Phillips St. #4
# Boston, MA 0211..." with entities "[(35, 41, 'SKILL'), (84, 93, 'SKILL'), (128, 138, ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
# PHILLIP R. GOETZE
# goetze@glorietageo.com
#
# T..." with entities "[(12, 13, 'SKILL'), (42, 45, 'SKILL'), (70, 91, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Epoch 0 Training Losses: {'ner': np.float32(14795.417)}
# C:\Users\dehem\anaconda3\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Elizabeth L. Richeson, Ph.D., M.S. PsyPharm
# Practi..." with entities "[(23, 25, 'SKILL'), (30, 31, 'SKILL'), (44, 52, 'S...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 18
#      16     doc = nlp(text)
#      17     example = Example.from_dict(doc, annotations)
# ---> 18     scorer.score(example)
#      20 print(f"Epoch {epoch} Validation scores:", scorer.scores)
#
# File ~\anaconda3\Lib\site-packages\spacy\scorer.py:151, in Scorer.score(self, examples, per_component)
#     149         scores["tokenizer"] = self.nlp.tokenizer.score(examples, **self.cfg)
#     150     else:
# --> 151         scores.update(self.nlp.tokenizer.score(examples, **self.cfg))  # type: ignore
#     152 for name, component in self.nlp.pipeline:
#     153     if hasattr(component, "score"):
#
# File ~\anaconda3\Lib\site-packages\spacy\tokenizer.pyx:758, in spacy.tokenizer.Tokenizer.score()
#
# File ~\anaconda3\Lib\site-packages\spacy\training\example.pyx:53, in spacy.training.example.validate_examples()
#
# TypeError: [E978] The Tokenizer.score method takes a list of Example objects, but got: <class 'spacy.training.example.Example'>
